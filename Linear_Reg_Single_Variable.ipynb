# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %% [markdown]
# ## Steps of the project of Simple Linear Regression
#
# ### 0. Import library and other dependencies
# ### 1. Read the Data from file or other source
# ### 2. Plot it and see pattern it follows
# ### 3. Fit the model on linear regression -> Best Fit line
# ### 4. 2-dimension -> X-Axis & y-axis -> 1-Dimension
#
#
# ## Goal - find coeeficient and

# %%
df = pd.read_csv('homeprices.csv')
df
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
plt.xlabel('Area(sqft)')
plt.ylabel('Price($)')
plt.scatter(df.area,df.price,c='red',marker='*')
plt.plot(df.area,reg.predict(df[['area']]),color='blue')

# %%
reg = LinearRegression()

# %%
reg.fit(df[['area']],df.price)
# Out:
# LinearRegression()

# %%
predict_value = [[2600]]   #2-Dimension as Input to Predict 
reg.predict(predict_value)
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([533664.38356164])

# %%
reg.coef_
# Out:
# array([135.78767123])

# %%
reg.intercept_
# Out:
# 180616.43835616432

# %%
# y = m*x+b
135.7876*3300+180616.43835616432,135.7876*5000+180616.43835616432
# Out:
# (628715.5183561643, 859554.4383561644)

# %%
df1 = pd.read_csv("areas.csv")
df1.head()
# Out:
#    area
# 0  1000
# 1  1500
# 2  2300
# 3  3540
# 4  4120

# %%
predict_price=reg.predict(df1[['area']])

# %%
df1['price'] = predict_price

# %%
df1
# Out:
#     area         price
# 0   1000  3.164041e+05
# 1   1500  3.842979e+05
# 2   2300  4.929281e+05
# 3   3540  6.613048e+05
# 4   4120  7.400616e+05
# 5   4560  7.998082e+05
# 6   5490  9.260908e+05
# 7   3460  6.504418e+05
# 8   4750  8.256079e+05
# 9   2300  4.929281e+05
# 10  9000  1.402705e+06
# 11  8600  1.348390e+06
# 12  7100  1.144709e+06

# %%
df1.to_csv('prediction.csv',index=False)

# %% [markdown]
# ### Exercise

# %%
df = pd.read_csv("canada_per_capita_income.csv")
df
# Out:
#     year  per capita income (US$)
# 0   1970              3399.299037
# 1   1971              3768.297935
# 2   1972              4251.175484
# 3   1973              4804.463248
# 4   1974              5576.514583
# 5   1975              5998.144346
# 6   1976              7062.131392
# 7   1977              7100.126170
# 8   1978              7247.967035
# 9   1979              7602.912681
# 10  1980              8355.968120
# 11  1981              9434.390652
# 12  1982              9619.438377
# 13  1983             10416.536590
# 14  1984             10790.328720
# 15  1985             11018.955850
# 16  1986             11482.891530
# 17  1987             12974.806620
# 18  1988             15080.283450
# 19  1989             16426.725480
# 20  1990             16838.673200
# 21  1991             17266.097690
# 22  1992             16412.083090
# 23  1993             15875.586730
# 24  1994             15755.820270
# 25  1995             16369.317250
# ...

# %%
plt.xlabel('Year')
plt.ylabel('Income')
plt.title('Per Capita Income')
plt.scatter(df['year'],df['per capita income (US$)'],marker='*',c='g')
plt.plot(df['year'],linear_reg.predict(df[['year']]),color='blue')

# %%
from sklearn.linear_model import LinearRegression


linear_reg = LinearRegression()
linear_reg.fit(df[['year']],df['per capita income (US$)'])
# Out:
# LinearRegression()

# %%
linear_reg.predict([[2020]])
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([41288.69409442])

# %% [markdown]
# ## Pickle Concept

# %%
import pickle

# %%
with open('model_pickle','wb') as f:
    pickle.dump(linear_reg,f)

# %%
with open('model_pickle','rb') as f:
    model = pickle.load(f)

# %%
model.predict([[5000]])
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([2510114.61825809])
